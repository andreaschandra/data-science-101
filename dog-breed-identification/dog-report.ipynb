# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt

# %%
history = pickle.load(open("history_dog.pkl", "rb"))

# %%
plt.plot(history["running_loss"], label="train")
plt.plot(history["running_loss_v"], label="val")

# %%
plt.plot(history["running_acc"], label="train")
plt.plot(history["running_acc_v"], label="val")
